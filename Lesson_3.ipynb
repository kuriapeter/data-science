# %% [markdown]
# <a href="https://colab.research.google.com/github/kuriapeter/data-science/blob/main/Lesson_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/Pinchez') #Create a virtual drive
# Out:
# Drive already mounted at /content/Pinchez; to attempt to forcibly remount, call drive.mount("/content/Pinchez", force_remount=True).

# %%
import pandas as pd
mydata=pd.read_csv('//content/drive/MyDrive/Colab Notebooks/Pinchez/TRC.csv')
print(mydata)
# Out:
#           TRC    Unnamed: 1      Unnamed: 2
# 0        Index         Item          Volume
# 1            1   Classrooms             256
# 2            2     ICT labs              10
# 3            3    Libraries               3
# 4            4     Vehicles               8
# 5          NaN          NaN             NaN
# 6            5     Lectures              50
# 7            6     Students            2300
# 8            7   Co workers              78

# %%
import matplotlib.pyplot as plt
import pandas as pd
kuria = pd.read_csv('//content/drive/MyDrive/Colab Notebooks/Pinchez/medal.csv')
country_data = kuria["country"]
medal_data = kuria["gold_medal"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
explode = (0, 0.1, 0., 0, 0)
plt.pie(medal_data, labels=country_data, explode=explode, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 Summer Olympics")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
kuria = pd.read_csv('//content/drive/MyDrive/Colab Notebooks/Pinchez/medal.csv')
country_data = kuria["country"]
medal_data = kuria["gold_medal"]
plt.bar(country_data, medal_data, label="MY DATA", color='c')
plt.plot()
plt.xlabel("country_data")
plt.ylabel("medal_data")
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 Summer Olympics")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
wainaina = pd.read_csv('//content/drive/MyDrive/Colab Notebooks/Pinchez/medal.csv')
country_data = wainaina["country"]
medal_data = wainaina["gold_medal"]
plt.bar(country_data, medal_data, label="AWARD", color='g')
fig, ax = plt.subplots(figsize = (16, 9))
ax.barh(country_data, medal_data)
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
ax.xaxis.grid(True, color ='grey',
        linestyle ='-', linewidth = 1.5,
        alpha = 0.5)
ax.set_axisbelow(True)
ax.invert_yaxis()
plt.plot()
plt.ylabel("country_data")
plt.xlabel("medal_data")
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 Summer Olympics")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import pandas as pd
wainaina = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Pinchez/medal.csv')
country_data = wainaina["country"]
medal_data = wainaina["gold_medal"]
plt.plot(country_data, medal_data, label="Distribution",color='g')
plt.plot()
plt.xlabel("country_data")
plt.ylabel("medal_data")
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 Summer Olympics")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Importing necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
names = ["Abraham Lincoln", "John Kennedy", "David Beckham", "Jeremy David", "Enock Ariel", "Delmar Javier"]
english = [97, 87, 89, 83, 85, 93]
database = [78, 87, 83, 81, 97, 76]
calculus = [75, 89, 70, 85, 89, 79]
computer_support = [73, 76, 77, 87, 99, 87]
ai = [87, 83, 82, 89, 76, 81]
total = [410, 422, 401, 425, 446, 416]


# Bar chart visualization
plt.figure(figsize=(10,6))
barWidth = 0.15

# Set position of bar on X axis
r1 = np.arange(len(names))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]

# Make the plot
plt.bar(r1, english, color='blue', width=barWidth, edgecolor='grey', label='English')
plt.bar(r2, database, color='green', width=barWidth, edgecolor='grey', label='Database')
plt.bar(r3, calculus, color='red', width=barWidth, edgecolor='grey', label='Calculus')
plt.bar(r4, computer_support, color='purple', width=barWidth, edgecolor='grey', label='Computer Support')
plt.bar(r5, ai, color='orange', width=barWidth, edgecolor='grey', label='AI')

# Add labels
plt.xlabel('Names', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(names))], names, rotation=45)
plt.ylabel('Scores')
plt.title('Scores in Different Subjects by Student')

# Create legend & Show graphic
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # positions the legend box outside the upper-left corner of the axes.
plt.tight_layout()
plt.show()

# Line graph visualization
plt.figure(figsize=(10,6))
for i, subject in enumerate([english, database, calculus, computer_support, ai]):
    plt.plot(names, subject, marker='v', label=['English', 'Database', 'Calculus', 'Computer Support', 'AI'][i])

# Add labels
plt.xlabel('Names')
plt.ylabel('Scores')
plt.title('Line Graph of Scores by Subject')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Pie chart visualization of total scores
plt.figure(figsize=(8,8))
plt.pie(total, labels=names, autopct='%1.1f%%', startangle=140, colors=['blue', 'green', 'red', 'purple', 'orange', 'yellow'])
plt.title('Total Scores Distribution among Students')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
wainaina = pd.read_csv('//content/drive/MyDrive/Colab Notebooks/Pinchez/regular.csv')
x = wainaina["StudentID "]
y = wainaina["TestScore"]
plt.plot(x, y, label="Performance",color='c')
plt.plot()
plt.xlabel("StudentID")
plt.ylabel("TestScore")
plt.title("StudentID\n"+"AGAINST TestScore")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
wainaina = pd.read_csv('//content/drive/MyDrive/Colab Notebooks/Pinchez/Line graph.csv')
age_data = wainaina["Age"]
salary_data = wainaina["Salary"]
plt.bar(age_data, salary_data, label="AWARD", color='g')
fig, ax = plt.subplots(figsize = (16, 9))
#ax.barh(age_data, salary_data)
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
ax.xaxis.grid(True, color ='grey',
                    linestyle ='-', linewidth = 1.5,
        alpha = 0.5)
ax.set_axisbelow(True)
ax.invert_yaxis()
plt.plot()
plt.ylabel("country_data")
plt.xlabel("medal_data")
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 Summer Olympics")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
